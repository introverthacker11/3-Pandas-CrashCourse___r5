# %%
import pandas as pd

a = pd.read_csv('colors(csvfile5).csv')
a

a.duplicated() # this shows number of duplicated values
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
a.duplicated().sum()
# Out:
# 0

# %%
b = pd.concat([a,a])
b
# Out:
#     Colors       Fruits         Cars      Cities  Integers  float
# 0    Green        Mango      Corolla     Karachi         1  1.200
# 1   Golden       Banana        Civic      Lahore         4  3.400
# 2     Blue       Orange        Hilux      Makkah         6  9.800
# 3   Yellow         Kiwi        Prado      Madina         2  7.600
# 4   Orange        Berry       Cultus  Islam Abad         3  9.760
# 5   Purple       Grapes        Camry  Hyder Abad         8  3.090
# 6    Brown        Apple        Supra    Peshawer         7  0.005
# 7   Silver  Watermmelon      Bugatti        Gaza         9  4.980
# 8     Grey       Cherry  Lamborghini       Kabul         7  6.650
# 9    White       Papaya      Ferrari      Tehran         6  3.600
# 10     Red      Coconut     Formula1    Istanbul         2  9.780
# 0    Green        Mango      Corolla     Karachi         1  1.200
# 1   Golden       Banana        Civic      Lahore         4  3.400
# ...

# %%
b.duplicated().sum()
# Out:
# 11

# %%
b.shape, a.shape
# Out:
# ((22, 6), (11, 6))

# %%
b[b.duplicated()] # this method is used to print duplicated values
# Out:
#     Colors       Fruits         Cars      Cities  Integers  float
# 0    Green        Mango      Corolla     Karachi         1  1.200
# 1   Golden       Banana        Civic      Lahore         4  3.400
# 2     Blue       Orange        Hilux      Makkah         6  9.800
# 3   Yellow         Kiwi        Prado      Madina         2  7.600
# 4   Orange        Berry       Cultus  Islam Abad         3  9.760
# 5   Purple       Grapes        Camry  Hyder Abad         8  3.090
# 6    Brown        Apple        Supra    Peshawer         7  0.005
# 7   Silver  Watermmelon      Bugatti        Gaza         9  4.980
# 8     Grey       Cherry  Lamborghini       Kabul         7  6.650
# 9    White       Papaya      Ferrari      Tehran         6  3.600
# 10     Red      Coconut     Formula1    Istanbul         2  9.780

# %%
c = a.sample(3)
c
# Out:
#    Colors       Fruits     Cars    Cities  Integers  float
# 6   Brown        Apple    Supra  Peshawer         7  0.005
# 7  Silver  Watermmelon  Bugatti      Gaza         9  4.980
# 3  Yellow         Kiwi    Prado    Madina         2  7.600

# %%
d = pd.concat([a,c])
d
# Out:
#     Colors       Fruits         Cars      Cities  Integers  float
# 0    Green        Mango      Corolla     Karachi         1  1.200
# 1   Golden       Banana        Civic      Lahore         4  3.400
# 2     Blue       Orange        Hilux      Makkah         6  9.800
# 3   Yellow         Kiwi        Prado      Madina         2  7.600
# 4   Orange        Berry       Cultus  Islam Abad         3  9.760
# 5   Purple       Grapes        Camry  Hyder Abad         8  3.090
# 6    Brown        Apple        Supra    Peshawer         7  0.005
# 7   Silver  Watermmelon      Bugatti        Gaza         9  4.980
# 8     Grey       Cherry  Lamborghini       Kabul         7  6.650
# 9    White       Papaya      Ferrari      Tehran         6  3.600
# 10     Red      Coconut     Formula1    Istanbul         2  9.780
# 6    Brown        Apple        Supra    Peshawer         7  0.005
# 7   Silver  Watermmelon      Bugatti        Gaza         9  4.980
# ...

# %%
d.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 6      True
# 7      True
# 3      True
# dtype: bool

# %%
d[d.duplicated()] # this method is used to print duplicated values
# Out:
#    Colors       Fruits     Cars    Cities  Integers  float
# 6   Brown        Apple    Supra  Peshawer         7  0.005
# 7  Silver  Watermmelon  Bugatti      Gaza         9  4.980
# 3  Yellow         Kiwi    Prado    Madina         2  7.600

# %% [markdown]
# ###
# ## Droping Duplicated Rows:
# ###

# %%
d[~d.duplicated()]
d
# Out:
#     Colors       Fruits         Cars      Cities  Integers  float
# 0    Green        Mango      Corolla     Karachi         1  1.200
# 1   Golden       Banana        Civic      Lahore         4  3.400
# 2     Blue       Orange        Hilux      Makkah         6  9.800
# 3   Yellow         Kiwi        Prado      Madina         2  7.600
# 4   Orange        Berry       Cultus  Islam Abad         3  9.760
# 5   Purple       Grapes        Camry  Hyder Abad         8  3.090
# 6    Brown        Apple        Supra    Peshawer         7  0.005
# 7   Silver  Watermmelon      Bugatti        Gaza         9  4.980
# 8     Grey       Cherry  Lamborghini       Kabul         7  6.650
# 9    White       Papaya      Ferrari      Tehran         6  3.600
# 10     Red      Coconut     Formula1    Istanbul         2  9.780

# %%
d.drop_duplicates( inplace = True )
d
# Out:
#     Colors       Fruits         Cars      Cities  Integers  float
# 0    Green        Mango      Corolla     Karachi         1  1.200
# 1   Golden       Banana        Civic      Lahore         4  3.400
# 2     Blue       Orange        Hilux      Makkah         6  9.800
# 3   Yellow         Kiwi        Prado      Madina         2  7.600
# 4   Orange        Berry       Cultus  Islam Abad         3  9.760
# 5   Purple       Grapes        Camry  Hyder Abad         8  3.090
# 6    Brown        Apple        Supra    Peshawer         7  0.005
# 7   Silver  Watermmelon      Bugatti        Gaza         9  4.980
# 8     Grey       Cherry  Lamborghini       Kabul         7  6.650
# 9    White       Papaya      Ferrari      Tehran         6  3.600
# 10     Red      Coconut     Formula1    Istanbul         2  9.780
